# %%
import pandas as pd

# %%
df_results = pd.read_csv('evolutionary_experiment_results.csv')
df_results
# Out:
#     Experiment  Best Fitness  Mean Fitness  Median Fitness  Worst Fitness  \
# 0            1   6348.455273   6630.199088     6392.993844   14368.049245
# 1            2   6321.649827   6896.169180     6346.369956   43897.931827
# 2            3   6296.680425   6927.358737     6350.122208   26558.390808
# 3            4   6271.883637   6802.008618     6300.090747   27473.506085
# 4            5   6272.316925   7056.820270     6308.744342   34525.416510
# ..         ...           ...           ...             ...            ...
# 95          96   6267.577837   6506.926821     6272.692884   11775.250779
# 96          97   6267.577837   6482.981290     6276.906155   10772.927185
# 97          98   6267.577837   6611.881491     6267.577837   19515.029826
# 98          99   6267.577837   6672.138364     6276.242304   16097.707704
# 99         100   6267.577837   6601.219358     6273.239302   24184.327447
#
#     Standard Deviation  Number of Unique Individuals  \
# ...

# %%
# Best Fitness	Mean Fitness	Median Fitness	Worst Fitness	Standard Deviation	Number of Unique Individuals	Number of Feasible Individuals	Number of Infeasible Individuals
ls_measures_cols = ['Best Fitness', 'Mean Fitness', 'Median Fitness', 'Worst Fitness', 'Standard Deviation', 'Number of Unique Individuals', 'Number of Feasible Individuals', 'Number of Infeasible Individuals']
df_results[ls_measures_cols].describe()
# Out:
#        Best Fitness  Mean Fitness  Median Fitness  Worst Fitness  \
# count    100.000000    100.000000      100.000000     100.000000
# mean    6269.391921   6559.106324     6275.366888   16241.118114
# std       10.070696    141.673760       17.565379   10087.467842
# min     6267.577837   6432.166924     6267.577837    9523.676902
# 25%     6267.577837   6490.596264     6267.578242   11198.530442
# 50%     6267.578242   6525.547861     6270.705037   12657.852443
# 75%     6267.578242   6559.386658     6274.947346   16300.292060
# max     6348.455273   7201.651442     6392.993844   72720.994642
#
#        Standard Deviation  Number of Unique Individuals  \
# count          100.000000                     100.00000
# mean           768.495164                     170.49000
# std            553.870341                      19.99924
# min            370.297452                     120.00000
# 25%            500.507257                     158.00000
# ...
